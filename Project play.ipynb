# %%
import matplotlib

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5,6,7,8]
y=[10,11,12,13,14,15,16,17]

# %%
plt.scatter(x,y)

# %%
plt.plot(x,y)

# %%
print(y)
# Out:
# [10, 11, 12, 13, 14, 15, 16, 17]

# %%
plt.scatter(x,y)

# %%
plt.plot(x,y)

# %%
noobieskills=['Raymond','Diaz','Santiago','Linetti','Boyle','Mcgonagle','Harry','Weasly']

# %%
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])

# %%
ax.bar(noobieskills,y)
plt.show()

# %%
plt.show()

# %%
ax.bar(noobieskills,y)
plt.show()

# %%
len(noobieskills)
# Out:
# 8

# %%
print(len(noobieskills))
# Out:
# 8

# %%
print(len(y))
# Out:
# 8

# %%
plt.show()

# %%
ax.bar(noobieskills,y)
# Out:
# <BarContainer object of 8 artists>

# %%
print(noobieskills)
# Out:
# ['Raymond', 'Diaz', 'Santiago', 'Linetti', 'Boyle', 'Mcgonagle', 'Harry', 'Weasly']

# %%
print(y)
# Out:
# [10, 11, 12, 13, 14, 15, 16, 17]

# %%
xlabel="Players"
fig = plt.figure(figsize = (10, 10)) 
plt.bar(noobieskills,y,color="Purple",width=0.5)
plt.xlabel("Players")
plt.ylabel("No. of kills")
plt.title("Kill count of noob players")
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt  
  
data = {'C':20, 'C++':15, 'Java':30,  
        'Python':35} 
courses = list(data.keys()) 
values = list(data.values()) 
   
fig = plt.figure(figsize = (10, 5)) 
  
# creating the bar plot 
plt.bar(courses, values, color ='maroon',  
        width = 0.4) 
  
plt.xlabel("Courses offered") 
plt.ylabel("No. of students enrolled") 
plt.title("Students enrolled in different courses") 
plt.show()

# %% [markdown]
# plt.scatter(noobieskills,y,color="green")

# %%
plt.plot(noobieskills,y)

# %%
plt.plot(y,noobieskills,color="brown")

# %%
plt.plot(y,noobieskills,color="maroon")

# %%
#asian paints year analysis
plt.figure(figsize = (10, 10))
apya={'2017':899,'2018':1158,'2019':1366,'mid2020':1812.25}
apyear=list(apya.keys())
apvalue=list(apya.values())
zerolist=[0,0,0,0]
plt.plot(apyear,apvalue,marker='x',markersize=9,markeredgecolor= 'red')
plt.plot(apyear,apvalue,color='blue')

plt.xlabel("Year")
plt.ylabel("Price of stock")

plt.title("Asian Paints stock price")
# Out:
# Text(0.5, 1.0, 'Asian Paints stock price')

# %%
plt.scatter(apyear,apvalue)

# %%
plt.bar(apyear,apvalue)
# Out:
# <BarContainer object of 4 artists>

# %%
dir(plt)
# Out:
# ['Annotation',
#  'Arrow',
#  'Artist',
#  'AutoLocator',
#  'Axes',
#  'Button',
#  'Circle',
#  'Figure',
#  'FigureCanvasBase',
#  'FixedFormatter',
#  'FixedLocator',
#  'FormatStrFormatter',
#  'Formatter',
#  'FuncFormatter',
#  'GridSpec',
#  'IndexLocator',
#  'Line2D',
#  'LinearLocator',
#  'Locator',
#  'LogFormatter',
#  'LogFormatterExponent',
#  'LogFormatterMathtext',
#  'LogLocator',
#  'MaxNLocator',
#  'MultipleLocator',
#  'Normalize',
#  'NullFormatter',
#  'NullLocator',
#  'Number',
#  'PolarAxes',
#  'Polygon',
#  'Rectangle',
#  'ScalarFormatter',
#  'Slider',
#  'Subplot',
#  'SubplotTool',
#  'Text',
#  'TickHelper',
#  'Widget',
#  '_INSTALL_FIG_OBSERVER',
#  '_IP_REGISTERED',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_auto_draw_if_interactive',
#  '_backend_mod',
#  '_get_running_interactive_framework',
#  '_interactive_bk',
#  '_log',
#  '_pylab_helpers',
# ...

# %%
plt.pie(y,labels=noobieskills)

plt.show()

# %%
plt.pie(apvalue,labels=apyear)
# Out:
# ([<matplotlib.patches.Wedge at 0x7feddc75df50>,
# ...
#  [Text(0.9437757585259212, 0.5650551456440531, '2017'),
#   Text(-0.2218272852394853, 1.0774008796744508, '2018'),
#   Text(-1.0881572595610778, -0.16097757130894125, '2019'),
#   Text(0.5111673736508489, -0.9740163839047543, 'mid2020')])

# %%
plt.pie(apvalue,labels=apyear)
plt.show()

# %%
plt.pie(y,labels=noobieskills)
# Out:
# ([<matplotlib.patches.Wedge at 0x7feddc876250>,
# ...
#  [Text(1.0537884665555075, 0.31548354593321076, 'Raymond'),
#   Text(0.6822590598436937, 0.862857216033568, 'Diaz'),
#   Text(2.57473582461959e-08, 1.0999999999999999, 'Santiago'),
#   Text(-0.7312754422021867, 0.821727587240441, 'Linetti'),
#   Text(-1.0981389733221336, 0.06395932512941886, 'Boyle'),
#   Text(-0.7778174593052025, -0.7778174593052023, 'Mcgonagle'),
#   Text(0.1277022320581751, -1.0925621904163443, 'Harry'),
#   Text(0.9682215375394291, -0.5220603932925618, 'Weasly')])

# %%
fig = plt.figure(figsize = (10, 10)) 
x=np.arange(0,10,0.1)
a=np.cos(x)
b=np.sin(x)
plt.plot(x,a,'b')
plt.plot(x,b,'r',linestyle="dashed")
plt.plot(x,a,marker='x',markersize=9,markeredgecolor= 'red')
plt.plot(x,b,marker='x',markersize=9,markeredgecolor= 'blue')

# %%
fig = plt.figure(dpi=80)
ax = fig.add_subplot(1,1,1)

table_data=[['Name','Price in rupees','Downloads'],['Angry Birds',75,197000],["Teen Titan",120,209000],
            ['Marvel comics',190,414000],['ColorMe',245,196000],['Fun Run',550,272000],['Crazy Taxi',55,311000],
           ['Igram Pro',175,213000],['Wapp pro',75,455000],['Math Formula',140,278000]]



table = ax.table(cellText=table_data, loc='center')
table.set_fontsize(14)
table.scale(1,4)
ax.axis('off')
plt.show()

# %%
fig = plt.figure(figsize = (12, 13)) 
copiesdict={'Angry Birds':197000,"Teen Titan":209000,
            'Marvel comics':414000,'ColorMe':196000,'Fun Run':272000,'Crazy Taxi':311000,
           'Igram Pro':213000,'Wapp pro':455000,'Math Formula':278000}
x=copiesdict.keys()
y=copiesdict.values()

plt.bar(x,y,color="Maroon")

plt.xlabel("Name of Game")
plt.ylabel("No. of copies sold")
plt.title("No of sold copies for various games")
plt.show()

# %%
plt.pie(copiesdict.values(),labels=copiesdict.keys())
plt.show()

# %%
music=["Despacito","Baby Shark Dance","Shape of You","See You Again",
       "Masha and the Bear – Recipe for Disaster","Johny Johny Yes Papa","Uptown Funk","Gangnam Style",
       "Learning Colors – Colorful Eggs on a Farm","Sorry"]

artist_name=["Luis Fonsi",'Pinkfong Kids',"Ed Sheeran","Wiz Khalifa ","Get Movies"
            ,"LooLoo Kids","Mark Ronson ","Psy","Miroshka TV","Justin Bieber"]

hitsonyoutube=[7.02,6.92,5.03,4.78,4.35,4.07,3.98,3.83,3.65,3.35]

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(30,10))
plt.bar(music,hitsonyoutube)
plt.xlabel("Name of song")
plt.ylabel("Number of views in billions")
plt.title("THE TOP 10 MOST VIEWED SONGS ON YOUTUBE ")
# Out:
# Text(0.5, 1.0, 'THE TOP 10 MOST VIEWED SONGS ON YOUTUBE ')

# %%
import matplotlib.pyplot as plt
figure=plt.figure(figsize=(20,10))
plt.bar(artist_name,hitsonyoutube)

plt.xlabel("Name of artist")
plt.ylabel("Number of views on youtube in billions")
plt.title("THE TOP 10 MOST VIEWED MUSIC ARTISTS ON YOUTUBE ")
#plt.pie(hitsonyoutube,labels=artist_name)
# Out:
# Text(0.5, 1.0, 'THE TOP 10 MOST VIEWED MUSIC ARTISTS ON YOUTUBE ')

# %%
fig=plt.figure(figsize=(10,10))
plt.pie(hitsonyoutube,labels=artist_name)
plt.title("Domination of various artist's in the recording field")

plt.show()

# %%
figure=plt.figure(figsize=(5,5))
plt.pie(hitsonyoutube,labels=artist_name)

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(hitsonyoutube,artist_name)
plt.show()
plt.plot(hitsonyoutube,music)
plt.show()
plt.plot(hitsonyoutube,artist_name)

plt.plot(hitsonyoutube,music)
plt.show()

# %%
figue=plt.figure(figsize=(20,10))
plt.bar(music,hitsonyoutube,color='red')
# Out:
# <BarContainer object of 10 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np


x=np.random.randint(1,10)
y=np.random.randint(1,10)
print("\n \n The random coordinate that was generrated was",x,",",y)

plt.plot(x,y,marker="d",markersize="10",markeredgecolor="blue")
plt.show()
# Out:
#
#  The random coordinate that was generrated was 2 , 8
